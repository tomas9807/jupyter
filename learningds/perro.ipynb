# %%
import numpy as np
import csv

with open('trips.csv') as f:
    trips = [  [float(element) for element in sublist] for sublist in list(csv.reader(f))[1:]]

# %%
ar = np.array(trips,dtype=float)

# %%
len_sec = ar[:,8]

# %%
len_sec
# Out:
# array([2.100e+01, 1.629e+01, 1.270e+01, 8.700e+00, 5.560e+00, 2.145e+01,
#        8.450e+00, 7.300e+00, 3.630e+01, 1.246e+01, 1.660e+01, 5.230e+00,
#        1.806e+01, 1.630e+01, 7.970e+00, 1.209e+01, 1.730e+01, 1.374e+01,
#        1.757e+01, 9.500e+00, 9.300e+00, 1.010e+01, 2.057e+01, 7.900e+00,
#        1.733e+01, 2.034e+01, 2.150e+00, 9.510e+00, 8.090e+00, 7.800e+00,
#        1.022e+01, 1.797e+01, 2.053e+01, 8.500e+00, 1.643e+01, 1.050e+01,
#        1.796e+01, 1.697e+01, 1.140e+01, 1.780e+01, 2.140e+01, 1.510e+01,
#        1.230e+01, 1.947e+01, 1.562e+01, 1.250e+01, 7.990e+00, 8.960e+00,
#        4.700e+00, 1.189e+01, 9.000e+00, 9.030e+00, 5.560e+00, 4.840e+00,
#        1.752e+01, 1.686e+01, 1.998e+01, 1.070e+01, 1.010e+01, 1.900e+00,
#        1.891e+01, 1.199e+01, 1.320e+01, 1.634e+01, 1.122e+01, 1.369e+01,
#        1.010e+01, 1.790e+01, 2.005e+01, 1.764e+01, 9.090e+00, 1.170e+01,
#        1.127e+01, 6.880e+00, 9.100e+00, 1.815e+01, 2.106e+01, 1.687e+01,
# ...

# %%
len_h = len_sec/3600

# %%
len_h
# Out:
# array([5.83333333e-03, 4.52500000e-03, 3.52777778e-03, 2.41666667e-03,
#        1.54444444e-03, 5.95833333e-03, 2.34722222e-03, 2.02777778e-03,
#        1.00833333e-02, 3.46111111e-03, 4.61111111e-03, 1.45277778e-03,
#        5.01666667e-03, 4.52777778e-03, 2.21388889e-03, 3.35833333e-03,
#        4.80555556e-03, 3.81666667e-03, 4.88055556e-03, 2.63888889e-03,
#        2.58333333e-03, 2.80555556e-03, 5.71388889e-03, 2.19444444e-03,
#        4.81388889e-03, 5.65000000e-03, 5.97222222e-04, 2.64166667e-03,
#        2.24722222e-03, 2.16666667e-03, 2.83888889e-03, 4.99166667e-03,
#        5.70277778e-03, 2.36111111e-03, 4.56388889e-03, 2.91666667e-03,
#        4.98888889e-03, 4.71388889e-03, 3.16666667e-03, 4.94444444e-03,
#        5.94444444e-03, 4.19444444e-03, 3.41666667e-03, 5.40833333e-03,
#        4.33888889e-03, 3.47222222e-03, 2.21944444e-03, 2.48888889e-03,
#        1.30555556e-03, 3.30277778e-03, 2.50000000e-03, 2.50833333e-03,
# ...

# %%
ar.shape
# Out:
# (961, 16)
